# %%
import os
print(os.getcwd())
# Out:
# c:\Users\YooNi\OneDrive\Desktop\Majorana-Neutrino-Hunt\extracted_features_csv_files\eunice_csv_files\train_csv

# %%
import pandas as pd

# %%
df = pd.read_csv('train_all_features.csv')

# %%
df
# Out:
#                        id      ED     HWP           LQ80       PPR        SC
# 0               0_train_0  3409.0  2299.0 -717094.898532  0.719376  0.034655
# 1               1_train_0  3404.0  2446.0 -331957.541919  0.729709  0.035314
# 2               2_train_0  3411.0  2262.0 -425532.152706  0.715390  0.034915
# 3               3_train_0  3408.0  2833.0 -306980.459766  0.769375  0.034752
# 4               4_train_0  3406.0  2397.0 -362746.925366  0.728165  0.035132
# ...                   ...     ...     ...            ...       ...       ...
# 1039995  1039995_train_15  3403.0  2533.0 -278607.352936  0.737282  0.034943
# 1039996  1039996_train_15  3404.0  2426.0 -477777.966558  0.726646  0.034483
# 1039997  1039997_train_15  3409.0  2417.0 -466589.983952  0.730722  0.034517
# 1039998  1039998_train_15  3400.0  3799.0 -143212.214717  0.776054  0.036649
# 1039999  1039999_train_15  3407.0  2747.0 -309525.718176  0.754457  0.036093
#
# [1040000 rows x 6 columns]

# %%
import os

# confirm where you are
print("Current directory:", os.getcwd())

# save dataframe as gzip-compressed CSV
output_file = "train_all_features.csv.gz"

df.to_csv(
    output_file,
    index=False,
    compression="gzip"
)

print("Saved gzip file:", os.path.abspath(output_file))
# Out:
# Current directory: c:\Users\YooNi\OneDrive\Desktop\Majorana-Neutrino-Hunt\extracted_features_csv_files\eunice_csv_files\train_csv
# Saved gzip file: c:\Users\YooNi\OneDrive\Desktop\Majorana-Neutrino-Hunt\extracted_features_csv_files\eunice_csv_files\train_csv\train_all_features.csv.gz
